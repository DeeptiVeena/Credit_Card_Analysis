# %% [markdown]
# <a href="https://colab.research.google.com/github/DeeptiVeena/Credit_Card_Analysis/blob/main/Credit_card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style
print('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.7.1

# %%
df_card = pd.read_csv('https://raw.githubusercontent.com/DeeptiVeena/Credit_Card_Analysis/main/Credit%20card%20transactions%20-%20India%20-%20Simple.csv')

# %%
df_card.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4      4       Bengaluru, India   5-May-15       Gold    Bills      F  171574

# %%
df_card.shape # print the dimensions of the dataframe
# Out:
# (26052, 7)

# %%
df_card.corr()
# Out:
# <ipython-input-6-77d89b87aebe>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_card.corr()
#            index    Amount
# index   1.000000 -0.106806
# Amount -0.106806  1.000000

# %%
df_card['Exp Type'].value_counts()
# Out:
# Food             5463
# Fuel             5257
# Bills            5078
# Entertainment    4762
# Grocery          4754
# Travel            738
# Name: Exp Type, dtype: int64

# %%
import seaborn as sns

# %%
data=['City','Amount']

# %%
df=pd.DataFrame(data)

# %%
total_amount_per_city = df_card.groupby('City')['Amount'].sum()
total_amount_per_city
# Out:
# City
# Achalpur, India     1606641
# Adilabad, India     1769464
# Adityapur, India     963993
# Adoni, India        1575355
# Adoor, India         647725
#                      ...
# Zaidpur, India       723818
# Zamania, India       865634
# Zira, India         1640547
# Zirakpur, India      549663
# Zunheboto, India     466429
# Name: Amount, Length: 986, dtype: int64

# %%
sns.scatterplot(data=df, x='City', y ='total_amount_per_city')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-4672952eb152> in <cell line: 1>()
# ----> 1 sns.scatterplot(data=df, x='City', y ='total_amount_per_city')
#       2 plt.tight_layout()
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     608 ):
#     609
# --> 610     p = _ScatterPlotter(
#     611         data=data,
#     612         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     389         )
#     390
# --> 391         super().__init__(data=data, variables=variables)
#     392
#     393         self.legend = legend
#
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x= 'City',y=total_amount_per_city, color='blue', alpha=0.5)  # Scatter plot with blue color and transparency
plt.title('Scatter Plot')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-919f28f84e72> in <cell line: 2>()
#       1 plt.figure(figsize=(8, 6))
# ----> 2 plt.scatter(x= 'City',y=total_amount_per_city, color='blue', alpha=0.5)  # Scatter plot with blue color and transparency
#       3 plt.title('Scatter Plot')
#       4 plt.xlabel('X-axis Label')
#       5 plt.ylabel('Y-axis Label')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...

# %%
# Out:
#                        index       Date  Card Type Exp Type Gender  Amount
# City
# Delhi, India               0  29-Oct-14       Gold    Bills      F   82475
# Greater Mumbai, India      1  22-Aug-14   Platinum    Bills      F   32555
# Bengaluru, India           2  27-Aug-14     Silver    Bills      F  101738
# Greater Mumbai, India      3  12-Apr-14  Signature    Bills      F  123424
# Bengaluru, India           4   5-May-15       Gold    Bills      F  171574

# %%
'data dimensions:', df_card.shape
# Out:
# ('data dimensions:', (26052, 6))

# %%
Date = list(map(str, range(2013, 2015)))

# %%
# group countries by continents and apply sum() function
df_Citywise= df_card.groupby('City', axis=0).sum()

type(df_card.groupby('City', axis=0))

df_Citywise.head()
# Out:
# <ipython-input-19-a8803777713c>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_Citywise= df_card.groupby('City', axis=0).sum()
#                    index   Amount
# City
# Achalpur, India   154978  1606641
# Adilabad, India   181254  1769464
# Adityapur, India  101333   963993
# Adoni, India      151691  1575355
# Adoor, India      124902   647725

# %%
# autopct create %, start angle represent starting point
df_Citywise['Total'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow
                            )

plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.axis('equal') # Sets the pie chart to look like a circle.
plt.legend(labels=df_continents.index, loc='upper left')


plt.show()
